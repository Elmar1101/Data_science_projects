# %% [markdown]
# <a href="https://colab.research.google.com/github/Elmar1101/Social_links_profile_main/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
cars=pd.Series(['BMW','Tesla','Bugatti'])
cars
# Out:
# 0        BMW
# 1      Tesla
# 2    Bugatti
# dtype: object

# %%
colors=pd.Series(['Red','Blue','Black'])
colors
# Out:
# 0      Red
# 1     Blue
# 2    Black
# dtype: object

# %%
cars=pd.DataFrame({'Car': cars, 'Color':colors})
cars
# Out:
#        Car  Color
# 0      BMW    Red
# 1    Tesla   Blue
# 2  Bugatti  Black

# %%
# @title Car

from matplotlib import pyplot as plt
import seaborn as sns
cars.groupby('Car').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Out:
# --2024-12-20 12:03:05--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv’
#
# car-sales.csv       100%[===================>]     369  --.-KB/s    in 0s
#
# 2024-12-20 12:03:05 (5.80 MB/s) - ‘car-sales.csv’ saved [369/369]

# %%
df = pd.read_csv('/content/car-sales.csv')
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
df[['Make','Colour','Price']]
# Out:
#      Make Colour       Price
# 0  Toyota  White   $4,000.00
# 1   Honda    Red   $5,000.00
# 2  Toyota   Blue   $7,000.00
# 3     BMW  Black  $22,000.00
# 4  Nissan  White   $3,500.00
# 5  Toyota  Green   $4,500.00
# 6   Honda   Blue   $7,500.00
# 7   Honda   Blue   $7,000.00
# 8  Toyota  White   $6,250.00
# 9  Nissan  White   $9,700.00

# %%
df['Make']=='Toyota'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# 9    False
# Name: Make, dtype: bool

# %%
df[df['Make']=='Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
df[df['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
df[(df['Make']=='Toyota') & (df['Colour']=='White')]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
df[(df['Make']=='Toyota') | (df['Colour']=='White')]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df['Price'].sum()
# Out:
# '$4,000.00$5,000.00$7,000.00$22,000.00$3,500.00$4,500.00$7,500.00$7,000.00$6,250.00$9,700.00'

# %%
df['Doors'].min()
# Out:
# 3

# %%
df['Doors'].max()
# Out:
# 5

# %%
df['Doors'].mean()
# Out:
# 4.0

# %%
df.groupby(['Make']).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
df.groupby(['Make','Colour']).mean(numeric_only=True)
# Out:
#                Odometer (KM)  Doors
# Make   Colour
# BMW    Black         11179.0    5.0
# Honda  Blue          50218.0    4.0
#        Red           87899.0    4.0
# Nissan White        122347.5    4.0
# Toyota Blue          32549.0    3.0
#        Green         99213.0    4.0
#        White        105021.5    4.0

# %%
df.groupby(['Make','Colour']).mean(numeric_only=True).reset_index()
# Out:
#      Make Colour  Odometer (KM)  Doors
# 0     BMW  Black        11179.0    5.0
# 1   Honda   Blue        50218.0    4.0
# 2   Honda    Red        87899.0    4.0
# 3  Nissan  White       122347.5    4.0
# 4  Toyota   Blue        32549.0    3.0
# 5  Toyota  Green        99213.0    4.0
# 6  Toyota  White       105021.5    4.0

# %%
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
df['Make'].value_counts()
# Out:
# Make
# Toyota    4
# Honda     3
# Nissan    2
# BMW       1
# Name: count, dtype: int64

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df['Odometer (MILES)']=df['Odometer (KM)']/1.6
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (MILES)
# 0  Toyota  White         150043      4   $4,000.00         93776.875
# 1   Honda    Red          87899      4   $5,000.00         54936.875
# 2  Toyota   Blue          32549      3   $7,000.00         20343.125
# 3     BMW  Black          11179      5  $22,000.00          6986.875
# 4  Nissan  White         213095      4   $3,500.00        133184.375
# 5  Toyota  Green          99213      4   $4,500.00         62008.125
# 6   Honda   Blue          45698      4   $7,500.00         28561.250
# 7   Honda   Blue          54738      4   $7,000.00         34211.250
# 8  Toyota  White          60000      4   $6,250.00         37500.000
# 9  Nissan  White          31600      4   $9,700.00         19750.000

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (MILES)
# 0  Toyota  White         150043      4   $4,000.00         93776.875
# 1   Honda    Red          87899      4   $5,000.00         54936.875
# 2  Toyota   Blue          32549      3   $7,000.00         20343.125
# 3     BMW  Black          11179      5  $22,000.00          6986.875
# 4  Nissan  White         213095      4   $3,500.00        133184.375
# 5  Toyota  Green          99213      4   $4,500.00         62008.125
# 6   Honda   Blue          45698      4   $7,500.00         28561.250
# 7   Honda   Blue          54738      4   $7,000.00         34211.250
# 8  Toyota  White          60000      4   $6,250.00         37500.000
# 9  Nissan  White          31600      4   $9,700.00         19750.000

# %%
df.drop('Odometer (MILES)',axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (MILES)
# 0  Toyota  White         150043      4   $4,000.00         93776.875
# 1   Honda    Red          87899      4   $5,000.00         54936.875
# 2  Toyota   Blue          32549      3   $7,000.00         20343.125
# 3     BMW  Black          11179      5  $22,000.00          6986.875
# 4  Nissan  White         213095      4   $3,500.00        133184.375
# 5  Toyota  Green          99213      4   $4,500.00         62008.125
# 6   Honda   Blue          45698      4   $7,500.00         28561.250
# 7   Honda   Blue          54738      4   $7,000.00         34211.250
# 8  Toyota  White          60000      4   $6,250.00         37500.000
# 9  Nissan  White          31600      4   $9,700.00         19750.000

# %%
df.drop('Odometer (MILES)',axis=1, inplace=True)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df['Odometer (Mile)']=df['Odometer (KM)'].apply(lambda x:x/1.6)
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile)
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 6   Honda   Blue          45698      4   $7,500.00        28561.250
# 7   Honda   Blue          54738      4   $7,000.00        34211.250
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000

# %%
def currency(x):
    if "$" in x:
        return 'USD'
    else:
        return 'Unknown'
df['Currency']=df['Price'].apply(currency)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
df.drop([0,3,7],axis=0)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Odometer (Mile) Currency
# 1   Honda    Red          87899      4  $5,000.00        54936.875      USD
# 2  Toyota   Blue          32549      3  $7,000.00        20343.125      USD
# 4  Nissan  White         213095      4  $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4  $4,500.00        62008.125      USD
# 6   Honda   Blue          45698      4  $7,500.00        28561.250      USD
# 8  Toyota  White          60000      4  $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4  $9,700.00        19750.000      USD

# %%
df_copy=df.copy()
df_copy
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
'AbA'.replace('A','c')
# Out:
# 'cbc'

# %%
df_copy['Price']=df_copy['Price'].str.replace('$','')
df_copy['Price']=df_copy['Price'].str.replace('.','')
df_copy['Price']=df_copy['Price'].str.replace(',','')
df_copy
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   400000        93776.875      USD
# 1   Honda    Red          87899      4   500000        54936.875      USD
# 2  Toyota   Blue          32549      3   700000        20343.125      USD
# 3     BMW  Black          11179      5  2200000         6986.875      USD
# 4  Nissan  White         213095      4   350000       133184.375      USD
# 5  Toyota  Green          99213      4   450000        62008.125      USD
# 6   Honda   Blue          45698      4   750000        28561.250      USD
# 7   Honda   Blue          54738      4   700000        34211.250      USD
# 8  Toyota  White          60000      4   625000        37500.000      USD
# 9  Nissan  White          31600      4   970000        19750.000      USD

# %%
df_copy['Price']=df_copy['Price'].str.replace(' ','')
df_copy
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   400000        93776.875      USD
# 1   Honda    Red          87899      4   500000        54936.875      USD
# 2  Toyota   Blue          32549      3   700000        20343.125      USD
# 3     BMW  Black          11179      5  2200000         6986.875      USD
# 4  Nissan  White         213095      4   350000       133184.375      USD
# 5  Toyota  Green          99213      4   450000        62008.125      USD
# 6   Honda   Blue          45698      4   750000        28561.250      USD
# 7   Honda   Blue          54738      4   700000        34211.250      USD
# 8  Toyota  White          60000      4   625000        37500.000      USD
# 9  Nissan  White          31600      4   970000        19750.000      USD

# %%
df['Price'].str.replace('[\$\.\,]','',regex=True)
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
df.Price
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
df_copy['Price']=df_copy['Price'].astype(int)

# %%
df_copy['Price']=df_copy['Price']/100

# %%
df_copy
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   4000.0        93776.875      USD
# 1   Honda    Red          87899      4   5000.0        54936.875      USD
# 2  Toyota   Blue          32549      3   7000.0        20343.125      USD
# 3     BMW  Black          11179      5  22000.0         6986.875      USD
# 4  Nissan  White         213095      4   3500.0       133184.375      USD
# 5  Toyota  Green          99213      4   4500.0        62008.125      USD
# 6   Honda   Blue          45698      4   7500.0        28561.250      USD
# 7   Honda   Blue          54738      4   7000.0        34211.250      USD
# 8  Toyota  White          60000      4   6250.0        37500.000      USD
# 9  Nissan  White          31600      4   9700.0        19750.000      USD

# %%
df_copy.groupby(['Make'])['Price'].mean(numeric_only=True).reset_index()
# Out:
#      Make    Price
# 0     BMW  22000.0
# 1   Honda   6500.0
# 2  Nissan   6600.0
# 3  Toyota   5437.5

# %%
df_copy.to_excel('processed_cars_data.xlsx')

# %%
df_copy['Price'].plot()
# Out:
# <Axes: >

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
df_copy[(df_copy['Colour']=='White') & (df_copy['Price']>9000)]
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Odometer (Mile) Currency
# 9  Nissan  White          31600      4  9700.0          19750.0      USD

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales-missing-data.csv
# Out:
# --2024-12-20 12:09:55--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales-missing-data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 287 [text/plain]
# Saving to: ‘car-sales-missing-data.csv’
#
# car-sales-missing-d 100%[===================>]     287  --.-KB/s    in 0s
#
# 2024-12-20 12:09:55 (5.51 MB/s) - ‘car-sales-missing-data.csv’ saved [287/287]

# %%
df = pd.read_csv('/content/car-sales-missing-data.csv')
df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
df.isna()
# Out:
#     Make  Colour  Odometer  Doors  Price
# 0  False   False     False  False  False
# 1  False   False     False  False  False
# 2  False   False      True  False  False
# 3  False   False     False  False  False
# 4  False   False     False  False  False
# 5  False   False      True  False  False
# 6  False    True      True  False  False
# 7  False   False      True  False   True
# 8  False   False     False   True   True
# 9   True   False     False  False  False

# %%
df.isna().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
df.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
df.dropna(subset=['Price'],inplace=True)
df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 9     NaN  White   31600.0    4.0   $9,700

# %%
df['Odometer'].mean()
# Out:
# 98763.2

# %%
df['Odometer'].fillna(98763.2)
# Out:
# 0    150043.0
# 1     87899.0
# 2     98763.2
# 3     11179.0
# 4    213095.0
# 5     98763.2
# 6     98763.2
# 9     31600.0
# Name: Odometer, dtype: float64

# %%
df['Odometer']=df['Odometer'].fillna(df['Odometer'].mean(), inplace=True)
# Out:
# <ipython-input-62-59f93148381a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Odometer']=df['Odometer'].fillna(df['Odometer'].mean(), inplace=True)

# %%
df['Colour'].fillna('Missing')
# Out:
# 0      White
# 1        Red
# 2       Blue
# 3      Black
# 4      White
# 5      Green
# 6    Missing
# 9      White
# Name: Colour, dtype: object

# %%
df['Colour'].fillna(df['Colour'].mode()[0])
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6    White
# 9    White
# Name: Colour, dtype: object

# %%
df.rename(columns={'Odometer':'Odometer (KM)'},inplace=True)
df
# Out:
#      Make Colour Odometer (KM)  Doors    Price
# 0  Toyota  White          None    4.0   $4,000
# 1   Honda    Red          None    4.0   $5,000
# 2  Toyota   Blue          None    3.0   $7,000
# 3     BMW  Black          None    5.0  $22,000
# 4  Nissan  White          None    4.0   $3,500
# 5  Toyota  Green          None    4.0   $4,500
# 6   Honda    NaN          None    4.0   $7,500
# 9     NaN  White          None    4.0   $9,700

# %%
df['Make'].value_counts()
# Out:
# Make
# Toyota    3
# Honda     2
# BMW       1
# Nissan    1
# Name: count, dtype: int64

# %%
df['Make'].value_counts().reset_index()
# Out:
#      Make  count
# 0  Toyota      3
# 1   Honda      2
# 2     BMW      1
# 3  Nissan      1

# %%
df.groupby(['Make'])['Make'].count()
# Out:
# Make
# BMW       1
# Honda     2
# Nissan    1
# Toyota    3
# Name: Make, dtype: int64

# %%
table_A=pd.DataFrame({'ID':[1,2,3,4],'Name':['Alice','Bob','Charlie','David']})

table_B=pd.DataFrame({'ID':[4,3,2,1],'Age':[25,30,35,40]})

pd.merge(table_A,table_B, on='ID')
# Out:
#    ID     Name  Age
# 0   1    Alice   40
# 1   2      Bob   35
# 2   3  Charlie   30
# 3   4    David   25

# %%
table_A=pd.DataFrame({'ID1':[1,2,3,4],'Name':['Alice','Bob','Charlie','David']})

table_B=pd.DataFrame({'ID2':[4,3,2,1],'Age':[25,30,35,40]})

pd.merge(table_A,table_B, left_on='ID1',right_on='ID2')
# Out:
#    ID1     Name  ID2  Age
# 0    1    Alice    1   40
# 1    2      Bob    2   35
# 2    3  Charlie    3   30
# 3    4    David    4   25

# %%
data = [['Afghanistan', 'Asia', 652230, 25500100, 20343000000], ['Albania', 'Europe', 28748, 2831741, 12960000000], ['Algeria', 'Africa', 2381741, 37100000, 188681000000], ['Andorra', 'Europe', 468, 78115, 3712000000], ['Angola', 'Africa', 1246700, 20609294, 100990000000]]
world = pd.DataFrame(data, columns=['name', 'continent', 'area', 'population', 'gdp']).astype({'name':'object', 'continent':'object', 'area':'Int64', 'population':'Int64', 'gdp':'Int64'})

# %%
world[(world['population']>=25000000) |  (world['area']>=3000000)] [['name','population','area']]
# Out:
#           name  population     area
# 0  Afghanistan    25500100   652230
# 2      Algeria    37100000  2381741

# %%
data = [[1, 1], [1, 2], [1, 3], [2, 1], [2, 4]]
project = pd.DataFrame(data, columns=['project_id', 'employee_id']).astype({'project_id':'Int64', 'employee_id':'Int64'})
data = [[1, 'Khaled', 3], [2, 'Ali', 2], [3, 'John', 1], [4, 'Doe', 2]]
employee = pd.DataFrame(data, columns=['employee_id', 'name', 'experience_years']).astype({'employee_id':'Int64', 'name':'object', 'experience_years':'Int64'})

# %%
employee
# Out:
#    employee_id    name  experience_years
# 0            1  Khaled                 3
# 1            2     Ali                 2
# 2            3    John                 1
# 3            4     Doe                 2

# %%
merged=pd.merge(employee,project,on='employee_id')
merged.groupby(['project_id'])['experience_years'].mean().round(2)
merged.reset_index().rename(columns={'experience_years':'average_years'}, inplace=True)
